# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
df=pd.read_csv("student_depression_dataset.csv")

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# 3          '7-8 hours'       Moderate      BCA
# 4          '5-6 hours'       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
# 2                                    No               9.0              1.0
# 3                                   Yes               4.0              5.0
# 4                                   Yes               1.0              1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  object
#  11  Dietary Habits                         27901 non-null  object
#  12  Degree                                 27901 non-null  object
#  13  Have you ever had suicidal thoughts ?  27901 non-null  object
#  14  Work/Study Hours                       27901 non-null  float64
#  15  Financial Stress                       27901 non-null  object
#  16  Family History of Mental Illness       27901 non-null  object
#  17  Depression                             27901 non-null  int64
# dtypes: float64(7), int64(2), object(9)
# memory usage: 3.8+ MB

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# min        0.000000            0.000000          0.000000          0.000000
# 25%        6.290000            2.000000          0.000000          4.000000
# 50%        7.770000            3.000000          0.000000          8.000000
# 75%        8.920000            4.000000          0.000000         10.000000
# max       10.000000            5.000000          4.000000         12.000000
#
#          Depression
# count  27901.000000
# mean       0.585499
# std        0.492645
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
sns.countplot(data=df,x="Depression");

# %% [markdown]
# There more depressed students than non depressed

# %%
sns.countplot(data=df,x="Depression",hue="Age");

# %%
sns.countplot(data=df,x="Academic Pressure",hue="Depression");

# %% [markdown]
# Depression increases with work pressure

# %%
sns.countplot(data=df,x="Depression",hue="Gender");

# %% [markdown]
# More male students are depressed than female

# %%
sns.distplot(df["Age"]);
# Out:
# C:\Users\sreer\AppData\Local\Temp\ipykernel_34024\444590024.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"]);

# %%
df[df["Depression"]==1]["Age"].mean()
# Out:
# 24.88773261508325

# %%
df[df["Depression"]==0]["Age"].mean()
# Out:
# 27.142412451361867

# %% [markdown]
# On average, depressed students are older than non-depressed students

# %%
sns.countplot(data=df,x="Depression",hue="Sleep Duration");

# %% [markdown]
# Students who sleep less tends to be more depressed

# %%
sns.countplot(data=df,x="Sleep Duration",hue="Gender");
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=df,x="Age",hue="Sleep Duration");
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=df,x="Degree");
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# There are more class 12 students in the dataset

# %%
sns.countplot(data=df,x="Degree",hue="Depression");
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# There are more depressed students than non depressed students in each degree and class 12 has more than double depresssed students than non depresed ones

# %%
plt.hist(df["Academic Pressure"]);

# %% [markdown]
# Most students have an academic pressure between 4 and 5

# %%
sns.countplot(data=df,x="Depression",hue="Work/Study Hours");

# %% [markdown]
# Higher work or study hours also causes depression

# %%
sns.distplot(df["CGPA"]);
# Out:
# C:\Users\sreer\AppData\Local\Temp\ipykernel_34024\3508458716.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["CGPA"]);

# %%
sns.boxplot(data=df);
plt.xticks(rotation=90)
plt.show()

# %%
plt.grid()
sns.boxplot(data=df,x="Academic Pressure");

# %%
plt.grid()
sns.boxplot(data=df,x="Age");

# %%
plt.grid()
sns.boxplot(data=df,x="CGPA");

# %%
plt.grid()
sns.boxplot(data=df,x="Financial Stress");

# %%
plt.scatter(df["Academic Pressure"],df["Age"]);

# %%
plt.hist(data=df,x="Dietary Habits");

# %% [markdown]
# Most Students have unhealthy dietry habits

# %%
sns.countplot(data=df,x="Depression",hue="Dietary Habits");

# %% [markdown]
# Depressed students have unhealthy dietry habits

# %%
plt.hist(data=df,x="Age");

# %%
df.tail()
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 27896  140685  Female  27.0      Surat    Student                5.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27898  140689    Male  31.0  Faridabad    Student                3.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27896            0.0  5.75                 5.0               0.0
# 27897            0.0  9.40                 3.0               0.0
# 27898            0.0  6.61                 4.0               0.0
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#             Sleep Duration Dietary Habits      Degree  \
# 27896          '5-6 hours'      Unhealthy  'Class 12'
# 27897  'Less than 5 hours'        Healthy         MSc
# 27898          '5-6 hours'      Unhealthy          MD
# 27899  'Less than 5 hours'        Healthy  'Class 12'
# 27900  'Less than 5 hours'        Healthy         BCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 27896                                   Yes               7.0
# 27897                                    No               0.0
# 27898                                    No              12.0
# 27899                                   Yes              10.0
# 27900                                   Yes               2.0
#
#       Financial Stress Family History of Mental Illness  Depression
# 27896              1.0                              Yes           0
# 27897              3.0                              Yes           0
# 27898              2.0                               No           0
# 27899              5.0                               No           1
# 27900              3.0                              Yes           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  object
#  11  Dietary Habits                         27901 non-null  object
#  12  Degree                                 27901 non-null  object
#  13  Have you ever had suicidal thoughts ?  27901 non-null  object
#  14  Work/Study Hours                       27901 non-null  float64
#  15  Financial Stress                       27901 non-null  object
#  16  Family History of Mental Illness       27901 non-null  object
#  17  Depression                             27901 non-null  int64
# dtypes: float64(7), int64(2), object(9)
# memory usage: 3.8+ MB

# %%
df.isna().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df["Financial Stress"].value_counts()
# Out:
# Financial Stress
# 5.0    6715
# 4.0    5775
# 3.0    5226
# 1.0    5121
# 2.0    5061
# ?         3
# Name: count, dtype: int64

# %%
df["Financial Stress"].replace("?",np.nan,inplace=True)
# Out:
# C:\Users\sreer\AppData\Local\Temp\ipykernel_34024\561938975.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Financial Stress"].replace("?",np.nan,inplace=True)

# %%
df["Financial Stress"].value_counts()
# Out:
# Financial Stress
# 5.0    6715
# 4.0    5775
# 3.0    5226
# 1.0    5121
# 2.0    5061
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df["Financial Stress"]=df["Financial Stress"].astype("float64")

# %%
mean=df["Financial Stress"].mean()

# %%
df["Financial Stress"].fillna(mean)
# Out:
# 0        1.0
# 1        2.0
# 2        1.0
# 3        5.0
# 4        1.0
#         ...
# 27896    1.0
# 27897    3.0
# 27898    2.0
# 27899    5.0
# 27900    3.0
# Name: Financial Stress, Length: 27901, dtype: float64

# %%
feature=df.iloc[:,0:-1]
target=df["Depression"]

# %%
catcol=feature.select_dtypes("object").columns
catcol
# Out:
# Index(['Gender', 'City', 'Profession', 'Sleep Duration', 'Dietary Habits',
#        'Degree', 'Have you ever had suicidal thoughts ?',
#        'Family History of Mental Illness'],
#       dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
feature[catcol]=oe.fit_transform(feature[catcol])

# %%
feature.head()
# Out:
#    id  Gender   Age  City  Profession  Academic Pressure  Work Pressure  CGPA  \
# 0   2     1.0  33.0  51.0        12.0                5.0            0.0  8.97
# 1   8     0.0  24.0   5.0        12.0                2.0            0.0  5.90
# 2  26     1.0  31.0  44.0        12.0                3.0            0.0  7.03
# 3  30     0.0  28.0  49.0        12.0                3.0            0.0  5.59
# 4  32     0.0  25.0  18.0        12.0                4.0            0.0  8.13
#
#    Study Satisfaction  Job Satisfaction  Sleep Duration  Dietary Habits  \
# 0                 2.0               0.0             0.0             0.0
# 1                 5.0               0.0             0.0             1.0
# 2                 5.0               0.0             2.0             0.0
# 3                 2.0               0.0             1.0             1.0
# 4                 3.0               0.0             0.0             1.0
#
#    Degree  Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0     4.0                                    1.0               3.0
# 1    11.0                                    0.0               3.0
# 2     6.0                                    0.0               9.0
# 3     8.0                                    1.0               4.0
# 4    17.0                                    1.0               1.0
#
#    Financial Stress  Family History of Mental Illness
# 0               1.0                               0.0
# 1               2.0                               1.0
# 2               1.0                               1.0
# 3               5.0                               1.0
# 4               1.0                               0.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(feature,target,test_size=0.2,random_state=0)

# %%
x_train.head()
# Out:
#            id  Gender   Age  City  Profession  Academic Pressure  \
# 14195   71804     1.0  31.0  45.0        12.0                1.0
# 1247     6495     1.0  33.0   7.0        12.0                1.0
# 23479  118315     0.0  25.0  45.0        12.0                2.0
# 20140  101942     1.0  21.0  20.0        12.0                2.0
# 26269  132433     1.0  29.0  49.0        12.0                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 14195            0.0  8.89                 4.0               0.0
# 1247             0.0  6.37                 4.0               0.0
# 23479            0.0  9.44                 3.0               0.0
# 20140            0.0  6.79                 1.0               0.0
# 26269            0.0  7.85                 1.0               0.0
#
#        Sleep Duration  Dietary Habits  Degree  \
# 14195             0.0             3.0    16.0
# 1247              0.0             1.0    23.0
# 23479             0.0             3.0     3.0
# 20140             3.0             3.0     1.0
# 26269             2.0             3.0    12.0
#
#        Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 14195                                    1.0              10.0
# 1247                                     0.0               2.0
# 23479                                    1.0              12.0
# 20140                                    1.0               2.0
# 26269                                    0.0              12.0
#
#        Financial Stress  Family History of Mental Illness
# 14195               1.0                               1.0
# 1247                1.0                               0.0
# 23479               4.0                               0.0
# 20140               4.0                               0.0
# 26269               4.0                               0.0

# %%
y_train.head()
# Out:
# 14195    0
# 1247     0
# 23479    1
# 20140    1
# 26269    0
# Name: Depression, dtype: int64

# %%
from sklearn.impute import SimpleImputer

# Create imputer to fill missing values with the column mean
imputer = SimpleImputer(strategy='mean')

# Fit on training data and transform
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)  # don't fit again on test data

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()

# %%
linreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
ypred = linreg.predict(x_test)

# %%
ypred
# Out:
# array([1.13517214, 0.12971078, 1.19904228, ..., 0.68763541, 0.57625432,
#        0.85758841])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(y_test,ypred)
mse=mean_squared_error(y_test,ypred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,ypred)

# %%
print(f"MAE : {mae}\nMSE : {mse} \nRMSE : {rmse}\nAccuracy : {r2}")
# Out:
# MAE : 0.26342375201752993
# MSE : 0.1135272296549635
# RMSE : 0.3369380204948137
# Accuracy : 0.5329499941436768
